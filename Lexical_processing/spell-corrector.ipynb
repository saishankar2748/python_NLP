# %%
import re
from collections import Counter

# %%
# function to tokenise words
def words(document):
    "Convert text to lower case and tokenise the document"
    return re.findall(r'\w+', document.lower())

# %%
# create a frequency table of all the words of the document
all_words = Counter(words(open('big.txt').read()))

# %%
# check frequency of a random word, say, 'chair'
all_words['chair']
# Out:
# 135

# %%
# look at top 10 frequent words
all_words.most_common(10)
# Out:
# [('the', 79809),
#  ('of', 40024),
#  ('and', 38312),
#  ('to', 28765),
#  ('in', 22023),
#  ('a', 21124),
#  ('that', 12512),
#  ('he', 12401),
#  ('was', 11410),
#  ('it', 10681)]

# %%
def edits_one(word):
    "Create all edits that are one edit away from `word`."
    alphabets  = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes    = [left + right[1:] for left, right in splits if right]
    inserts    = [left + c + right for left, right in splits for c in alphabets]
    replaces   = [left + c + right[1:] for left, right in splits if right for c in alphabets]
    transposes = [left + right[1] + right[0] + right[2:] for left, right in splits if len(right)>1]
    return set(deletes + inserts + replaces + transposes)

# %%
def edits_two(word):
    "Create all edits that are two edits away from `word`."
    return (e2 for e1 in edits_one(word) for e2 in edits_one(e1))

# %%
def known(words):
    "The subset of `words` that appear in the `all_words`."
    return set(word for word in words if word in all_words)

# %%
def possible_corrections(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits_one(word)) or known(edits_two(word)) or [word])

# %%
def prob(word, N=sum(all_words.values())): 
    "Probability of `word`: Number of appearances of 'word' / total number of tokens"
    return all_words[word] / N

# %%
print(len(set(edits_one("monney"))))
print(edits_one("monney"))
# Out:
# 336
# {'monneiy', 'monneys', 'monbey', 'moqnney', 'money', 'monnezy', 'dmonney', 'monnec', 'monneq', 'monneoy', 'moynney', 'moniney', 'fonney', 'monnkey', 'mondey', 'moncney', 'vonney', 'monlney', 'monwney', 'moeney', 'molney', 'monnehy', 'monneyw', 'zmonney', 'monnuey', 'mponney', 'moznney', 'monneye', 'monneyy', 'monneyx', 'nmonney', 'monneu', 'monneo', 'wonney', 'monnen', 'monneyf', 'montey', 'mnnney', 'mcnney', 'mognney', 'moiney', 'mlnney', 'mfnney', 'mouney', 'mooney', 'xonney', 'monnew', 'modnney', 'oonney', 'mvnney', 'monnejy', 'mornney', 'monnepy', 'monnewy', 'qmonney', 'monrney', 'monnhy', 'monndy', 'monnaey', 'rmonney', 'monnegy', 'monneyc', 'monnmy', 'munney', 'lmonney', 'monhney', 'msnney', 'mowney', 'fmonney', 'monnky', 'monneqy', 'monneny', 'mosney', 'mnney', 'mlonney', 'mokney', 'monnevy', 'lonney', 'monneh', 'gmonney', 'moknney', 'mzonney', 'monnbey', 'mnonney', 'monnedy', 'monqey', 'monbney', 'monnyey', 'monpney', 'monneyp', 'mmnney', 'qonney', 'mdnney', 'monrey', 'monntey', 'monaey', 'mocney', 'monneyr', 'mwonney', 'monneby', 'momney', 'monneyt', 'mknney', 'motnney', 'ionney', 'monnei', 'ymonney', 'mownney', 'monneyn', 'monzey', 'tonney', 'monnem', 'maonney', 'muonney', 'mopnney', 'monniey', 'monxey', 'mosnney', 'tmonney', 'monnvey', 'monnyy', 'monoey', 'mtonney', 'donney', 'monnsy', 'imonney', 'omonney', 'monncey', 'mqnney', 'mxnney', 'mjnney', 'monneyu', 'monnay', 'monnly', 'monneuy', 'monneyb', 'bmonney', 'monneb', 'montney', 'monnqey', 'monhey', 'monley', 'monnley', 'monxney', 'monneyz', 'monncy', 'smonney', 'monnny', 'monnoy', 'mononey', 'monnemy', 'mhnney', 'monnesy', 'moanney', 'omnney', 'monngy', 'mopney', 'minney', 'monnes', 'pmonney', 'monfey', 'mionney', 'moniey', 'monnwey', 'moxnney', 'monneya', 'jmonney', 'ponney', 'monnty', 'jonney', 'mgnney', 'monnsey', 'monneym', 'moinney', 'monnep', 'monaney', 'mtnney', 'monfney', 'momnney', 'moncey', 'monned', 'monuey', 'mpnney', 'monvney', 'monnjey', 'monneyd', 'monnefy', 'menney', 'moneny', 'monnex', 'molnney', 'monnecy', 'monwey', 'monnek', 'kmonney', 'mdonney', 'monneyq', 'monnzy', 'hmonney', 'moenney', 'mondney', 'monnuy', 'monyey', 'monnjy', 'mounney', 'monnely', 'mnoney', 'monvey', 'monnej', 'mxonney', 'monner', 'monsey', 'monnfey', 'mmonney', 'monjney', 'mwnney', 'uonney', 'emonney', 'monnmey', 'gonney', 'monnrey', 'monnry', 'myonney', 'yonney', 'sonney', 'mofnney', 'monnhey', 'mongey', 'monneyg', 'monny', 'monnev', 'mohney', 'mronney', 'mocnney', 'modney', 'monnby', 'monzney', 'monnery', 'monnpey', 'monnet', 'monneky', 'mqonney', 'mohnney', 'monpey', 'ronney', 'mobney', 'monmey', 'zonney', 'honney', 'mhonney', 'monnel', 'monnwy', 'monnez', 'monngey', 'mfonney', 'mbonney', 'monneey', 'monney', 'monnqy', 'xmonney', 'amonney', 'morney', 'monnexy', 'wmonney', 'monmney', 'mongney', 'monkey', 'monneyj', 'bonney', 'mvonney', 'monne', 'vmonney', 'monnea', 'mojnney', 'monnxy', 'movney', 'monuney', 'monnee', 'monneyv', 'mznney', 'monsney', 'moxney', 'meonney', 'moonney', 'mojney', 'monjey', 'monnoey', 'moyney', 'mconney', 'monneay', 'aonney', 'eonney', 'monnef', 'moneey', 'monneyi', 'onney', 'monneyl', 'monnney', 'monnfy', 'mogney', 'monnety', 'mbnney', 'monkney', 'monniy', 'monnzey', 'monnpy', 'monnvy', 'monyney', 'mofney', 'motney', 'monqney', 'monneyk', 'monneg', 'cmonney', 'moaney', 'movnney', 'conney', 'mynney', 'mozney', 'mrnney', 'mjonney', 'monnye', 'mgonney', 'monneyh', 'monndey', 'msonney', 'moqney', 'konney', 'mobnney', 'moneney', 'monnxey', 'nonney', 'monneyo', 'manney', 'umonney', 'mkonney'}

# %%
print(known(edits_one("monney")))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at words that are two edits away
print(len(set(edits_two("monney"))))
print(known(edits_two("monney")))
# Out:
# 51013
# {'honey', 'manner', 'monkeys', 'money', 'donkey', 'monday', 'donne', 'moaned', 'bonnet', 'tonne', 'monkey', 'olney', 'donned', 'bonne', 'moines', 'convey', 'morley', 'manned', 'motley', 'bonny', 'monger'}

# %%
# Let's look at possible corrections of a word
print(possible_corrections("monney"))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at probability of a word
print(prob("money"))
print(prob("monkey"))
# Out:
# 0.0002922233626303688
# 5.378344097491451e-06

# %%
def spell_check(word):
    "Print the most probable spelling correction for `word` out of all the `possible_corrections`"
    correct_word = max(possible_corrections(word), key=prob)
    if correct_word != word:
        return "Did you mean " + correct_word + "?"
    else:
        return "Correct spelling."

# %%
# test spell check
print(spell_check("monney"))
# Out:
# Did you mean money?

# %%
print(spell_check("monny"))
# Out:
# Did you mean money?

# %%
word= 'san'
splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
splits
# Out:
# [('', 'san'), ('s', 'an'), ('sa', 'n'), ('san', '')]

# %%
deletes = [left + right[1:] for left, right in splits if right]
deletes
# Out:
# ['an', 'sn', 'sa']

# %%
alphabets    = 'abcdefghijklmnopqrstuvwxyz'
inserts = [left + c + right for left, right in splits for c in alphabets]
len(inserts)
# Out:
# 104

# %%
inserts
# Out:
# ['asan',
#  'bsan',
#  'csan',
#  'dsan',
#  'esan',
#  'fsan',
#  'gsan',
#  'hsan',
#  'isan',
#  'jsan',
#  'ksan',
#  'lsan',
#  'msan',
#  'nsan',
#  'osan',
#  'psan',
#  'qsan',
#  'rsan',
#  'ssan',
#  'tsan',
#  'usan',
#  'vsan',
#  'wsan',
#  'xsan',
#  'ysan',
#  'zsan',
#  'saan',
#  'sban',
#  'scan',
#  'sdan',
#  'sean',
#  'sfan',
#  'sgan',
#  'shan',
#  'sian',
#  'sjan',
#  'skan',
#  'slan',
#  'sman',
#  'snan',
#  'soan',
#  'span',
#  'sqan',
#  'sran',
#  'ssan',
#  'stan',
#  'suan',
#  'svan',
#  'swan',
#  'sxan',
#  'syan',
#  'szan',
#  'saan',
#  'sabn',
#  'sacn',
#  'sadn',
#  'saen',
#  'safn',
#  'sagn',
#  'sahn',
#  'sain',
#  'sajn',
#  'sakn',
#  'saln',
#  'samn',
#  'sann',
#  'saon',
#  'sapn',
#  'saqn',
#  'sarn',
#  'sasn',
#  'satn',
#  'saun',
#  'savn',
#  'sawn',
#  'saxn',
#  'sayn',
#  'sazn',
#  'sana',
#  'sanb',
#  'sanc',
#  'sand',
#  'sane',
#  'sanf',
#  'sang',
#  'sanh',
#  'sani',
#  'sanj',
#  'sank',
#  'sanl',
#  'sanm',
#  'sann',
#  'sano',
#  'sanp',
#  'sanq',
#  'sanr',
#  'sans',
#  'sant',
#  'sanu',
#  'sanv',
#  'sanw',
#  'sanx',
#  'sany',
#  'sanz']

# %%
replaces = [left + c + right[1:] for left, right in splits if right for c in alphabets]
len(replaces)
# Out:
# 78

# %%
replaces
# Out:
# ['aan',
#  'ban',
#  'can',
#  'dan',
#  'ean',
#  'fan',
#  'gan',
#  'han',
#  'ian',
#  'jan',
#  'kan',
#  'lan',
#  'man',
#  'nan',
#  'oan',
#  'pan',
#  'qan',
#  'ran',
#  'san',
#  'tan',
#  'uan',
#  'van',
#  'wan',
#  'xan',
#  'yan',
#  'zan',
#  'san',
#  'sbn',
#  'scn',
#  'sdn',
#  'sen',
#  'sfn',
#  'sgn',
#  'shn',
#  'sin',
#  'sjn',
#  'skn',
#  'sln',
#  'smn',
#  'snn',
#  'son',
#  'spn',
#  'sqn',
#  'srn',
#  'ssn',
#  'stn',
#  'sun',
#  'svn',
#  'swn',
#  'sxn',
#  'syn',
#  'szn',
#  'saa',
#  'sab',
#  'sac',
#  'sad',
#  'sae',
#  'saf',
#  'sag',
#  'sah',
#  'sai',
#  'saj',
#  'sak',
#  'sal',
#  'sam',
#  'san',
#  'sao',
#  'sap',
#  'saq',
#  'sar',
#  'sas',
#  'sat',
#  'sau',
#  'sav',
#  'saw',
#  'sax',
#  'say',
#  'saz']

# %%
transposes = [left + right[1] + right[0] + right[2:] for left, right in splits if len(right)>1]
transposes
# Out:
# ['asn', 'sna']

# %%
final = set(deletes + inserts + replaces + transposes)
final
# Out:
# {'aan',
#  'an',
#  'asan',
#  'asn',
#  'ban',
#  'bsan',
#  'can',
#  'csan',
#  'dan',
#  'dsan',
#  'ean',
#  'esan',
#  'fan',
#  'fsan',
#  'gan',
#  'gsan',
#  'han',
#  'hsan',
#  'ian',
#  'isan',
#  'jan',
#  'jsan',
#  'kan',
#  'ksan',
#  'lan',
#  'lsan',
#  'man',
#  'msan',
#  'nan',
#  'nsan',
#  'oan',
#  'osan',
#  'pan',
#  'psan',
#  'qan',
#  'qsan',
#  'ran',
#  'rsan',
#  'sa',
#  'saa',
#  'saan',
#  'sab',
#  'sabn',
#  'sac',
#  'sacn',
#  'sad',
#  'sadn',
#  'sae',
#  'saen',
#  'saf',
#  'safn',
#  'sag',
#  'sagn',
#  'sah',
#  'sahn',
#  'sai',
#  'sain',
#  'saj',
#  'sajn',
#  'sak',
#  'sakn',
#  'sal',
#  'saln',
#  'sam',
#  'samn',
#  'san',
#  'sana',
#  'sanb',
#  'sanc',
#  'sand',
#  'sane',
#  'sanf',
#  'sang',
#  'sanh',
#  'sani',
#  'sanj',
#  'sank',
#  'sanl',
#  'sanm',
#  'sann',
#  'sano',
#  'sanp',
#  'sanq',
#  'sanr',
#  'sans',
#  'sant',
#  'sanu',
#  'sanv',
#  'sanw',
#  'sanx',
#  'sany',
#  'sanz',
#  'sao',
#  'saon',
#  'sap',
#  'sapn',
#  'saq',
#  'saqn',
#  'sar',
#  'sarn',
#  'sas',
#  'sasn',
#  'sat',
#  'satn',
#  'sau',
#  'saun',
#  'sav',
#  'savn',
#  'saw',
#  'sawn',
#  'sax',
#  'saxn',
#  'say',
#  'sayn',
#  'saz',
#  'sazn',
#  'sban',
#  'sbn',
#  'scan',
#  'scn',
#  'sdan',
#  'sdn',
#  'sean',
#  'sen',
#  'sfan',
#  'sfn',
#  'sgan',
#  'sgn',
#  'shan',
#  'shn',
#  'sian',
#  'sin',
#  'sjan',
#  'sjn',
#  'skan',
#  'skn',
#  'slan',
#  'sln',
#  'sman',
#  'smn',
#  'sn',
#  'sna',
#  'snan',
#  'snn',
#  'soan',
#  'son',
#  'span',
#  'spn',
#  'sqan',
#  'sqn',
#  'sran',
#  'srn',
#  'ssan',
#  'ssn',
#  'stan',
#  'stn',
#  'suan',
#  'sun',
#  'svan',
#  'svn',
#  'swan',
#  'swn',
#  'sxan',
#  'sxn',
#  'syan',
#  'syn',
#  'szan',
#  'szn',
#  'tan',
#  'tsan',
#  'uan',
#  'usan',
#  'van',
#  'vsan',
#  'wan',
#  'wsan',
#  'xan',
#  'xsan',
#  'yan',
#  'ysan',
#  'zan',
#  'zsan'}

# %%
len(final)
# Out:
# 182

# %%
len(edits_one('san'))
# Out:
# 182

# %%
set(edits_two('san'))
# Out:
# {'sagnw',
#  'seanj',
#  'sapyn',
#  'sakn',
#  'msag',
#  'gany',
#  'seasn',
#  'sayo',
#  'aao',
#  'nanj',
#  'sfjn',
#  'jsian',
#  'xslan',
#  'smns',
#  'bsanr',
#  'csjan',
#  'szak',
#  'uian',
#  'shahn',
#  'stfan',
#  'sasi',
#  'hant',
#  'sjagn',
#  'sdnz',
#  'sein',
#  'wsaun',
#  'csayn',
#  'xesan',
#  'dsax',
#  'bxsan',
#  'sadnv',
#  'ysae',
#  'jsam',
#  'sthan',
#  'xin',
#  'wsna',
#  'sranb',
#  'xxan',
#  'xean',
#  'ar',
#  'ssnl',
#  'sqlan',
#  'csean',
#  'hsman',
#  'suhan',
#  'siu',
#  'dsanu',
#  'ssgan',
#  'ssbn',
#  'skain',
#  'sanoh',
#  'za',
#  'tqsan',
#  'wbn',
#  'saqwn',
#  'szon',
#  'rsjn',
#  'samsn',
#  'sxanq',
#  'sabnn',
#  'fanb',
#  'sanvz',
#  'qpn',
#  'stxn',
#  'zawn',
#  'syno',
#  'sznz',
#  'smxn',
#  'sahne',
#  'vand',
#  'psar',
#  'fanf',
#  'ysaan',
#  'esaln',
#  'nanb',
#  'asarn',
#  'szpan',
#  'sjfan',
#  'qaln',
#  'av',
#  'sansz',
#  'salun',
#  'usant',
#  'jan',
#  'satnj',
#  'sujan',
#  'nsfn',
#  'sudan',
#  'saent',
#  'rsgan',
#  'rszn',
#  'zsant',
#  'sffn',
#  'dsaxn',
#  'seapn',
#  'gsan',
#  'sasu',
#  'wasan',
#  'sajnd',
#  'lsajn',
#  'svj',
#  'csae',
#  'swabn',
#  'jmsan',
#  'sanwb',
#  'saonw',
#  'oar',
#  'sqam',
#  'bsap',
#  'fanl',
#  'nrsan',
#  'satjn',
#  'svany',
#  'vanw',
#  'smoan',
#  'ksak',
#  'hjsan',
#  'asnd',
#  'asajn',
#  'sagen',
#  'shni',
#  'gsanp',
#  'saml',
#  'sfm',
#  'esln',
#  'gjan',
#  'csaa',
#  'kkn',
#  'lrsan',
#  'wsqan',
#  'seang',
#  'smanv',
#  'zn',
#  'sxx',
#  'sejan',
#  'max',
#  'ngsan',
#  'sxanp',
#  'gban',
#  'fsgn',
#  'qln',
#  'wsgan',
#  'santn',
#  'vsafn',
#  'ae',
#  'vsang',
#  'seyan',
#  'aaq',
#  'uanf',
#  'saunu',
#  'pgan',
#  'sankl',
#  'sdxn',
#  'cao',
#  'sdnx',
#  'salk',
#  'spsn',
#  'jhn',
#  'saqs',
#  'szanr',
#  'sanyb',
#  'sygn',
#  'osabn',
#  'svaa',
#  'sakny',
#  'qscan',
#  'sarf',
#  'sne',
#  'zapn',
#  'gsap',
#  'shana',
#  'tun',
#  'spac',
#  'sqnn',
#  'tsah',
#  'sahz',
#  'xsna',
#  'ysxn',
#  'ewsan',
#  'sbr',
#  'satgn',
#  'smax',
#  'lsaon',
#  'absn',
#  'stak',
#  'gskn',
#  'vanj',
#  'isian',
#  'slaz',
#  'caon',
#  'syn',
#  'shnd',
#  'bsavn',
#  'askn',
#  'nean',
#  'oaon',
#  'shanr',
#  'ang',
#  'kasn',
#  'sabng',
#  'faan',
#  'sanpi',
#  'sanvx',
#  'sedan',
#  'xsadn',
#  'sknx',
#  'snman',
#  'wsak',
#  'skqn',
#  'sanoz',
#  'smane',
#  'usbn',
#  'thn',
#  'shnt',
#  'smaun',
#  'zsax',
#  'sanya',
#  'hsaon',
#  'ysamn',
#  'iahn',
#  'sanyc',
#  'scwan',
#  'ssani',
#  'sabne',
#  'mbsan',
#  'isean',
#  'lsaqn',
#  'sawi',
#  'sakzn',
#  'sasrn',
#  'wlsan',
#  'safu',
#  'sacni',
#  'shkan',
#  'lsadn',
#  'janq',
#  'seank',
#  'stapn',
#  'ysah',
#  'suwan',
#  'sjah',
#  'sabsn',
#  'saizn',
#  'gann',
#  'savx',
#  'smi',
#  'qwn',
#  'ejan',
#  'sjjan',
#  'rlan',
#  'pspan',
#  'ssazn',
#  'ojsan',
#  'sade',
#  'snqn',
#  'xfsan',
#  'esak',
#  'saja',
#  'dnsan',
#  'kan',
#  'jsab',
#  'sbawn',
#  'samu',
#  'banb',
#  'syqn',
#  'nand',
#  'sgnb',
#  'ysagn',
#  'snanu',
#  'stgan',
#  'sandj',
#  'qao',
#  'sjann',
#  'safw',
#  'sanlc',
#  'sany',
#  'bkan',
#  'sgai',
#  'ixan',
#  'soh',
#  'lsanh',
#  'samk',
#  'csfan',
#  'caw',
#  'hdsan',
#  'sdau',
#  'cani',
#  'snsa',
#  'satyn',
#  'uanp',
#  'swnx',
#  'sanps',
#  'rnn',
#  'sts',
#  'msban',
#  'suani',
#  'qen',
#  'yant',
#  'naun',
#  'shsn',
#  'tsank',
#  'zsag',
#  'hpan',
#  'ssar',
#  'rsgn',
#  'swgan',
#  'jsrn',
#  'hspan',
#  'sauvn',
#  'shabn',
#  'vsian',
#  'sanjn',
#  'tann',
#  'sanpy',
#  'sahvn',
#  'qspan',
#  'sanpd',
#  'qyn',
#  'asdn',
#  'szlan',
#  'saync',
#  'oano',
#  'myan',
#  'sanra',
#  'rsat',
#  'sazq',
#  'wsadn',
#  'sangu',
#  'smnp',
#  'bnsan',
#  'lsaan',
#  'sanst',
#  'scanr',
#  'svoan',
#  'sapgn',
#  'selan',
#  'shz',
#  'sanow',
#  'ayn',
#  'msmn',
#  'sljan',
#  'slane',
#  'spnb',
#  'svman',
#  'wgan',
#  'shgn',
#  'btan',
#  'sgjn',
#  'sagno',
#  'esazn',
#  'oaj',
#  'jzsan',
#  'jaz',
#  'satng',
#  'sanmr',
#  'savnk',
#  'snzan',
#  'mssn',
#  'rayn',
#  'sadon',
#  'hen',
#  'jsaon',
#  'wsap',
#  'aasan',
#  'ggsan',
#  'sul',
#  'sanec',
#  'syv',
#  'sajni',
#  'saenn',
#  'wnsan',
#  'rsmn',
#  'sannt',
#  'rsagn',
#  'zson',
#  'fman',
#  'squan',
#  'xoan',
#  'smzan',
#  'sxyan',
#  'savun',
#  'gnsan',
#  'lans',
#  'vsanc',
#  'smnq',
#  'szqn',
#  'ysxan',
#  'msaon',
#  'seatn',
#  'dsvan',
#  'dsun',
#  'sashn',
#  'siaxn',
#  'bsin',
#  'svanl',
#  'sasun',
#  'oaq',
#  'stfn',
#  'sbj',
#  'esana',
#  'aosan',
#  'qwsan',
#  'sxno',
#  'cajn',
#  'shng',
#  'sdc',
#  'sanff',
#  'sknf',
#  'sganp',
#  'saxnx',
#  'dsap',
#  'lae',
#  'snav',
#  'svo',
#  'sacs',
#  'yag',
#  'sabnu',
#  'ihsan',
#  'sdnr',
#  'swanu',
#  'sbaw',
#  'mksan',
#  'vcsan',
#  'lsanw',
#  'daz',
#  'rsa',
#  'sgcn',
#  'svane',
#  'banc',
#  'sanki',
#  'ksqn',
#  'swanz',
#  'sjahn',
#  'mdn',
#  'ysanw',
#  'sanxv',
#  'eanq',
#  'svwn',
#  'srad',
#  'xsann',
#  'xdsan',
#  'isaz',
#  'sdanp',
#  'szdn',
#  'aam',
#  'lscan',
#  'shyan',
#  'csanm',
#  'shar',
#  'lran',
#  'aanw',
#  'sqean',
#  'waxn',
#  'sqtn',
#  'ssatn',
#  'slban',
#  'xsman',
#  'saca',
#  'kin',
#  'naf',
#  'xang',
#  'sapkn',
#  'ssasn',
#  'spaun',
#  'osun',
#  'xaqn',
#  'zosan',
#  'sapnf',
#  'fshn',
#  'srran',
#  'sanug',
#  'asanv',
#  'saunv',
#  'sgaq',
#  'zsjan',
#  'snu',
#  'bsanx',
#  'xsanv',
#  'tanp',
#  'seaz',
#  'srai',
#  'snanl',
#  'ase',
#  'hsang',
#  'sanks',
#  'msanf',
#  'sanfd',
#  'ivan',
#  'sont',
#  'sbnan',
#  'awn',
#  'ganc',
#  'txsan',
#  'asac',
#  'paj',
#  'wyan',
#  'sjzn',
#  'zsaxn',
#  'pssn',
#  'capn',
#  'dsanp',
#  'awsn',
#  'sij',
#  'saevn',
#  'svaz',
#  'sgy',
#  'obn',
#  'sadh',
#  'sqaln',
#  'sanku',
#  'lsanq',
#  'gapn',
#  'dsane',
#  'seaqn',
#  'sdrn',
#  'sivn',
#  'mau',
#  'ksaf',
#  'osfan',
#  'yagn',
#  'sabx',
#  'csian',
#  'gran',
#  'sux',
#  'salkn',
#  'gwan',
#  'ab',
#  'ison',
#  'sgs',
#  'mn',
#  'spaxn',
#  'naan',
#  'scaqn',
#  'suahn',
#  'snx',
#  'sapx',
#  'seanp',
#  'jusan',
#  'haa',
#  'sqm',
#  'shf',
#  'wswn',
#  'sainx',
#  'sanum',
#  'samwn',
#  'satn',
#  'seau',
#  'scam',
#  'stana',
#  'bap',
#  'msarn',
#  'ddsan',
#  'jsaj',
#  'wsax',
#  'eant',
#  'saar',
#  'rqsan',
#  'svf',
#  'hxan',
#  'stanu',
#  'jsjan',
#  'swann',
#  'saanh',
#  'suarn',
#  'sando',
#  'wsatn',
#  'qsabn',
#  'ashan',
#  'yoan',
#  'xsanw',
#  'hanr',
#  'tisan',
#  'esaon',
#  'sini',
#  'tsvan',
#  'saunh',
#  'sqd',
#  'wsanv',
#  'sskan',
#  'ysag',
#  'lskn',
#  'sfnz',
#  'sxfn',
#  'fsjan',
#  'hanb',
#  'hsai',
#  'shnx',
#  'sjp',
#  'spag',
#  'pal',
#  'qcsan',
#  'ganh',
#  'usaln',
#  'spanz',
#  'dayn',
#  'sacan',
#  'dssan',
#  'snda',
#  'ksln',
#  'sban',
#  'sqaa',
#  'snfa',
#  'syane',
#  'saxfn',
#  'swnk',
#  'dadn',
#  'smajn',
#  'csano',
#  'sdanh',
#  'earn',
#  'sqny',
#  'szn',
#  'lsln',
#  'fban',
#  'sankq',
#  'spaan',
#  'sio',
#  'synd',
#  'uao',
#  'iszn',
#  'vain',
#  'sawt',
#  'saw',
#  'iav',
#  'ucn',
#  'gsanv',
#  'swh',
#  'isal',
#  'sandg',
#  'slzn',
#  'aaln',
#  'sn',
#  'skay',
#  'svian',
#  'saunn',
#  'sars',
#  'cpan',
#  'kskn',
#  'senz',
#  'hslan',
#  'samn',
#  'ssacn',
#  'iam',
#  'sdns',
#  'nsain',
#  'ysrn',
#  'swna',
#  'saqo',
#  'scaz',
#  'tsano',
#  'sait',
#  'lsaln',
#  'qsyan',
#  'sawcn',
#  'yyan',
#  'shaz',
#  'yani',
#  'ganw',
#  'srz',
#  'aqsan',
#  'sblan',
#  'sihn',
#  'krn',
#  'sbl',
#  'satg',
#  'usazn',
#  'ssanj',
#  'csain',
#  'snaen',
#  'jsaxn',
#  'eesan',
#  'sang',
#  'iak',
#  'srnf',
#  'pdn',
#  'msane',
#  'sgk',
#  'syan',
#  'bsanh',
#  'ssqan',
#  'asnw',
#  'sazz',
#  'tsane',
#  'asanp',
#  'wyn',
#  'nln',
#  'isdan',
#  'sfanh',
#  'wsazn',
#  'sycan',
#  'smkn',
#  'sxnx',
#  'kdn',
#  'slrn',
#  'hskn',
#  'saex',
#  'kaz',
#  'sadpn',
#  'siun',
#  'ysfan',
#  'sanuq',
#  'jaj',
#  'gsagn',
#  'tano',
#  'shamn',
#  'kqsan',
#  'sarxn',
#  'sksn',
#  'sam',
#  'sajnc',
#  'sxqan',
#  'sanyu',
#  'sdaq',
#  'sannq',
#  'sono',
#  'usen',
#  'suajn',
#  'sahpn',
#  'ksnan',
#  'hhsan',
#  'aat',
#  'asani',
#  'rgn',
#  'usanp',
#  'spazn',
#  'nnsan',
#  'hosan',
#  'stb',
#  'sanmu',
#  'saqh',
#  'rsao',
#  'dahn',
#  'saxnu',
#  'sjnp',
#  'savin',
#  'psfn',
#  'hzan',
#  'uan',
#  'syawn',
#  'fah',
#  'szvn',
#  'sjao',
#  'soaln',
#  'saynf',
#  'rdsan',
#  'sanzf',
#  'ebn',
#  'uskan',
#  'saxtn',
#  'waq',
#  'osdan',
#  'gcn',
#  'sanhd',
#  'waln',
#  'sxun',
#  'sykn',
#  'bdan',
#  'dazn',
#  'pcsan',
#  'fsak',
#  'jsann',
#  'kvn',
#  'fsax',
#  'syman',
#  'saqp',
#  'lsak',
#  'qanz',
#  'kad',
#  'hanu',
#  'saony',
#  'seano',
#  'skanb',
#  'ihan',
#  'sryn',
#  'ysban',
#  'jsean',
#  'zans',
#  'sajn',
#  'sahzn',
#  'zap',
#  'scq',
#  'pswn',
#  'shaen',
#  'cqsan',
#  'spasn',
#  'sndan',
#  'fasn',
#  'rsaen',
#  'dsen',
#  'smak',
#  'saahn',
#  'sxanf',
#  'lsab',
#  'snanm',
#  'saqvn',
#  'wcn',
#  'rsacn',
#  'saeen',
#  'asa',
#  'kuan',
#  'cdan',
#  'sbs',
#  'sanjc',
#  'sjane',
#  'sffan',
#  'sek',
#  'esank',
#  'sgaln',
#  'aanp',
#  'efan',
#  'suni',
#  'escn',
#  'saof',
#  'sru',
#  'sjaxn',
#  'canm',
#  'iban',
#  'szaun',
#  'gadn',
#  'sianj',
#  'dsqan',
#  'iaqn',
#  'sanpx',
#  'siak',
#  'ssat',
#  'sqqn',
#  'stajn',
#  'sanai',
#  'eanf',
#  'dsaw',
#  'sdae',
#  'sgnk',
#  'tnan',
#  'psuan',
#  'jqan',
#  'sea',
#  'baon',
#  'sawny',
#  'okan',
#  'sacmn',
#  'xa',
#  'dsaj',
#  'xak',
#  'raj',
#  'spax',
#  'sqai',
#  'santw',
#  'srnc',
#  'saoen',
#  'day',
#  'zanv',
#  'usapn',
#  'sxacn',
#  'qano',
#  'panr',
#  'kafn',
#  'bgn',
#  'soon',
#  'snanc',
#  'sbab',
#  'maan',
#  'sjkan',
#  'iag',
#  'snae',
#  'sqz',
#  'svanc',
#  'isun',
#  'sayzn',
#  'sgni',
#  'mpn',
#  'sabnj',
#  'sldn',
#  'at',
#  'sakon',
#  'fxsan',
#  'ianw',
#  'sfanv',
#  'rsaun',
#  'lstan',
#  'shqan',
#  'soqan',
#  'csahn',
#  'opan',
#  'svp',
#  'sxaf',
#  'fhn',
#  'saonv',
#  'xani',
#  'iun',
#  'psane',
#  'ptn',
#  'skaa',
#  'sunq',
#  'sqann',
#  'sainy',
#  'shaan',
#  'sazo',
#  'sanch',
#  'saaqn',
#  'rain',
#  'saznc',
#  'sswan',
#  'tsasn',
#  'sanxh',
#  'snanf',
#  'exan',
#  'pran',
#  'samfn',
#  'fsaan',
#  'suao',
#  'wsoan',
#  'oas',
#  'spcan',
#  'dsman',
#  'srl',
#  'skyn',
#  'gnan',
#  'usanm',
#  'psban',
#  'bsau',
#  'sxaan',
#  'gsamn',
#  'sanfq',
#  'sjana',
#  'sacd',
#  'misan',
#  'msanl',
#  'sazm',
#  'hanz',
#  'ksat',
#  'ssabn',
#  'fssan',
#  'samw',
#  'xsaq',
#  'sbcn',
#  'lsank',
#  'rswan',
#  'usnn',
#  'dszan',
#  'saosn',
#  'hayn',
#  'jln',
#  'isang',
#  'jabn',
#  'manz',
#  'sign',
#  'qmsan',
#  'anc',
#  'ascan',
#  'saf',
#  'sbnr',
#  'soanc',
#  'qnan',
#  'ssamn',
#  'sasnl',
#  'sanpb',
#  'yanu',
#  'jysan',
#  'sbano',
#  'srnj',
#  'assn',
#  'saynv',
#  'sdnb',
#  'zcsan',
#  'fgan',
#  'swe',
#  'rank',
#  'spane',
#  'zfsan',
#  'slqan',
#  'hsane',
#  'sanqp',
#  'sancq',
#  'asaxn',
#  'yavn',
#  'rslan',
#  'sqawn',
#  'saxnj',
#  'sanjg',
#  'saxw',
#  'sjs',
#  'sagnr',
#  'snaun',
#  'rsdn',
#  'sabrn',
#  'uajn',
#  'txn',
#  'zysan',
#  'sjax',
#  'swo',
#  'szm',
#  'oam',
#  'nsjn',
#  'asnz',
#  'zanm',
#  'sailn',
#  'saep',
#  'sunu',
#  'ian',
#  'sbm',
#  ...}

# %%
len(set(edits_two('san')))
# Out:
# 14352

# %%
possible_corrections('sherlo')
# Out:
# {'hello',
#  'hero',
#  'sero',
#  'shelf',
#  'shell',
#  'shells',
#  'sherlock',
#  'sherry',
#  'sterno',
#  'thermo'}

# %%
spell_check('sherlo')
# Out:
# 'Did you mean sherlock?'

# %%
possible_corrections('emfasize')
# Out:
# {'emphasize'}

# %%
from spell_corrector import rectify
correct = rectify("snam")
print(correct)
# Out:
# snap

# %%
import re
ww = 'The Nobel Prize is a set of five annual international awards bestowed in several categories by Swedish and Norwegian institutions in recognition of academic, cultural or scientific advances. The Nobel family, known for their innovations in the oil industry in Azerbaijan, was the leading representative of foreign capital in Baku in the 19th century. Alfred Nobel’s personal fortune was funded by the personal fortune, the Nobel Prize. The Board of the Nobel Foundation decided that after this addition, no new prizes would be granted'
ww = ww.lower()
len(re.findall(('\w+'),string = ww))
# Out:
# 85

# %%
re.findall('nobel prize',ww)
# Out:
# ['nobel prize', 'nobel prize']
